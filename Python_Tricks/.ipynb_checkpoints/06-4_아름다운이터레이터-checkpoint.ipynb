# %% [markdown]
# 파이썬의 이터레이터 프로토콜
# - __ iter__ 및 __ next__ 던더 메서드를 지원하는 객체는 for-in 반복문에서 자동으로 작동함.

# %% [markdown]
# 무한반복

# %%
class Repeater:
    def __init__(self, value):
        self.value = value
        
    def __iter__(self):
        return RepeaterIterator(self)

class RepeaterIterator:
    def __init__(self, source):
        self.source = source
        
    def __next__(self):
        return self.source.value

# %%
# 무한반복이므로 멈추자.
repeater = Repeater('Hello')
for item in repeater:
    print(item)

# %% [markdown]
# 파이썬에서 for-in 반복문은 어떻게 동작할까?

# %%
repeater = Repeater('Hello')
iterator = repeater.__iter__()
while True:
    item = iterator.__next__()
    print(item)
# Out:
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# ...

# %%
# 위의 무한반복을 수동으로 에뮬레이트 해보자.
repeater = Repeater('Hello')
iterator = iter(repeater)
next(iterator)
# Out:
# 'Hello'

# %%
next(iterator)
# Out:
# 'Hello'

# %%
next(iterator)
# Out:
# 'Hello'

# %% [markdown]
# 더 단순한 이터레이터 클래스
# - 하나의 클래스로 __ next__와 __ iter__를 제공하자.

# %%
class Repeater:
    def __init__(self, value):
        self.value = value
        
    def __iter__(self):
        return self
    
    def __next__(self):
        return self.value

# %% [markdown]
# 누가 무한반복을 원하겠는가

# %%
my_list = [1, 2, 3]
iterator = iter(my_list)
next(iterator)
# Out:
# 1

# %%
next(iterator)
# Out:
# 2

# %%
next(iterator)
# Out:
# 3

# %%
next(iterator) # 다 쓰고 난뒤에는 StopIteration 예외가 호출됨.
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-13-4ce711c44abc> in <module>()
# ----> 1 next(iterator)
#
# StopIteration:

# %%
# 정해진 횟수만큼 반복된 후에 멈추는 BoundedRepeater 클래스를 작성하자.
class BoundedRepeater:
    def __init__(self, value, max_repeats):
        self.value = value
        self.max_repeats = max_repeats
        self.count = 0
        
    def __iter__(self):
        return self
    
    def __next__(self):
        if self.count >= self.max_repeats:
            raise StopIteration
        self.count += 1
        return self.value

# %%
repeater = BoundedRepeater('Hello', 3)
for item in repeater:
    print(item)
# Out:
# Hello
# Hello
# Hello

# %%
repeater = BoundedRepeater('Hello', 3)
iterator = iter(repeater)
while True:
    try:
        item = next(iterator)
    except StopIteration:
        break
    print(item)
# Out:
# Hello
# Hello
# Hello
